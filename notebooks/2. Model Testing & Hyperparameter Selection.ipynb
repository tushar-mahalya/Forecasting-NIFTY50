# %%
# Hardware configuration 
# Using tf-gpu-310 Conda Env
import tensorflow as tf
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 749744972349004341
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14497349632
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9967127212681109444
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# Importing important libraries
import os
import json

# Setting root folder as current working directory
os.chdir('/home/studio-lab-user/sagemaker-studiolab-notebooks/Forecasting-NIFTY50')

# Importing modules from Source Code
from src.pipeline.testing import test_models
from src.components.models import all_models

# %%
# Creating the dictionary of the data_map.json file
with open('/home/studio-lab-user/sagemaker-studiolab-notebooks/Forecasting-NIFTY50/artifacts/data_map.json', 'r') as file:
    data_map = json.load(file)

# %%
# Creating seperate dict containing only {"ticker":"normalized data path"} 
# to input in testing pipeline
norm_data_dict = dict()
for ticker in data_map.keys():
    norm_data_dict[ticker] = data_map[ticker]['Normalized Data']

# %% [markdown]
# ## Testing Pipeline
# In order to determine the optimal model, window size, and sequencing for a specific dataset, an exhaustive search algorithm will be employed. This algorithm systematically tests every combination of parameters to identify the model that yields the lowest testing error. The chosen model will be saved along with training logs for further analysis.
#
# The following parameters will be explored during the exhaustive search:
#
# 1. **Models**:
#     * Simple LSTM Model: A basic Long Short-Term Memory (LSTM) model.
#     * Dynamic LSTM Model: An LSTM model with dynamic architecture (No. of LSTM cells in a layer is proportional to the window size).
#     * Bidirectional LSTM Model: An LSTM model that processes input sequences in both forward and backward directions.
#     * Stacked LSTM Model: An LSTM model with multiple layers for enhanced representation learning (Two consecutive layers having LSTM cells).
# 2. **Sequences**:
#     * Simple Univariate Sequence: A sequence consisting of a single variable or feature (Closing price of the day).
#     * Multivariate Sequences: Sequences containing multiple variables or features (Closing price, MFI & Log Returns).
# 3. **Window Sizes**:
#     * 5 Days Values: A window of five consecutive days' worth of data.
#     * 1 Week Values: A window encompassing one week's worth of data.
#     * 10 Days Values: A window spanning ten consecutive days' worth of data.
#     * 2 Weeks Values: A window comprising two weeks' worth of data.
#
# By exhaustively testing all possible combinations of these parameters, the algorithm aims to identify the model and parameter configuration that demonstrates the lowest testing error. The selected model will be saved (at '/models' directory), training logs and the information of best performing model will be saved (at '/artifacts' directory) for further analysis and evaluation. This approach ensures a thorough exploration of the parameter space to maximize the model's performance for each specific stock's data.

# %%
# Importing my LSTM Models with different configurations for testing
my_models = all_models()
my_models
# Out:
# {'Fixed': <function src.components.models.simple_model(X, y, learn_rate, model_name=None)>,
#  'Dynamic': <function src.components.models.dynamic_model(X, y, learn_rate, model_name=None)>,
#  'Bidirectional': <function src.components.models.bidirectional_model(X, y, learn_rate, model_name=None)>,
#  'Stacked': <function src.components.models.stacked_model(X, y, learn_rate, model_name=None)>}

# %%
# Defining hyperparameters 
window_size_list = [5,7,10,14]
epochs = 200

# %%
# Testing Pipeline
test_models(data_dict = norm_data_dict,
            epochs = epochs,
            models = my_models,
            window_sizes = window_size_list)
# Out:
# ================================ NSE : ADANIENT ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0032	Testing error: 0.0354
#   > Model: Dynamic         Param count: 146 	Training error: 0.0040	Testing error: 0.0435
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0035	Testing error: 0.0518
#   > Model: Stacked         Param count: 806 	Training error: 0.0041	Testing error: 0.0315
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0038	Testing error: 0.0535
#   > Model: Dynamic         Param count: 260 	Training error: 0.0028	Testing error: 0.0336
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0029	Testing error: 0.0190
#   > Model: Stacked         Param count: 806 	Training error: 0.0036	Testing error: 0.0325
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0029	Testing error: 0.0332
#   > Model: Dynamic         Param count: 491 	Training error: 0.0030	Testing error: 0.0342
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0028	Testing error: 0.0202
#   > Model: Stacked         Param count: 806 	Training error: 0.0044	Testing error: 0.0463
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0038	Testing error: 0.0445
#   > Model: Dynamic         Param count: 911 	Training error: 0.0029	Testing error: 0.0256
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0029	Testing error: 0.0369
#   > Model: Stacked         Param count: 806 	Training error: 0.0045	Testing error: 0.0541
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0019	Testing error: 0.0503
#   > Model: Dynamic         Param count: 186 	Training error: 0.0022	Testing error: 0.0443
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0020	Testing error: 0.0714
#   > Model: Stacked         Param count: 886 	Training error: 0.0019	Testing error: 0.0751
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0026	Testing error: 0.0577
#   > Model: Dynamic         Param count: 316 	Training error: 0.0017	Testing error: 0.0549
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0015	Testing error: 0.0504
#   > Model: Stacked         Param count: 886 	Training error: 0.0019	Testing error: 0.0509
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0023	Testing error: 0.0529
#   > Model: Dynamic         Param count: 571 	Training error: 0.0016	Testing error: 0.0605
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0016	Testing error: 0.0467
#   > Model: Stacked         Param count: 886 	Training error: 0.0020	Testing error: 0.0531
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0017	Testing error: 0.1176
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0016	Testing error: 0.0541
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0017	Testing error: 0.0373
#   > Model: Stacked         Param count: 886 	Training error: 0.0017	Testing error: 0.1335
#
# ================================ NSE : ADANIPORTS ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0156	Testing error: 0.0090
#   > Model: Dynamic         Param count: 146 	Training error: 0.0132	Testing error: 0.0091
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0135	Testing error: 0.0095
#   > Model: Stacked         Param count: 806 	Training error: 0.0138	Testing error: 0.0094
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0136	Testing error: 0.0088
#   > Model: Dynamic         Param count: 260 	Training error: 0.0131	Testing error: 0.0088
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0131	Testing error: 0.0087
#   > Model: Stacked         Param count: 806 	Training error: 0.0146	Testing error: 0.0089
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0149	Testing error: 0.0087
#   > Model: Dynamic         Param count: 491 	Training error: 0.0132	Testing error: 0.0091
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0140	Testing error: 0.0097
#   > Model: Stacked         Param count: 806 	Training error: 0.0180	Testing error: 0.0108
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0143	Testing error: 0.0090
#   > Model: Dynamic         Param count: 911 	Training error: 0.0130	Testing error: 0.0099
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0135	Testing error: 0.0129
#   > Model: Stacked         Param count: 806 	Training error: 0.0148	Testing error: 0.0089
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0120	Testing error: 0.0108
#   > Model: Dynamic         Param count: 186 	Training error: 0.0121	Testing error: 0.0130
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0121	Testing error: 0.0160
#   > Model: Stacked         Param count: 886 	Training error: 0.0108	Testing error: 0.0109
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0124	Testing error: 0.0135
#   > Model: Dynamic         Param count: 316 	Training error: 0.0107	Testing error: 0.0123
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0104	Testing error: 0.0149
#   > Model: Stacked         Param count: 886 	Training error: 0.0090	Testing error: 0.0163
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0110	Testing error: 0.0132
#   > Model: Dynamic         Param count: 571 	Training error: 0.0095	Testing error: 0.0220
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0081	Testing error: 0.0147
#   > Model: Stacked         Param count: 886 	Training error: 0.0091	Testing error: 0.0177
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0116	Testing error: 0.0098
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0081	Testing error: 0.0318
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0085	Testing error: 0.0172
#   > Model: Stacked         Param count: 886 	Training error: 0.0093	Testing error: 0.0259
#
# ================================ NSE : APOLLOHOSP ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0170	Testing error: 0.0139
#   > Model: Dynamic         Param count: 146 	Training error: 0.0159	Testing error: 0.0122
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0139	Testing error: 0.0115
#   > Model: Stacked         Param count: 806 	Training error: 0.0158	Testing error: 0.0136
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0146	Testing error: 0.0118
#   > Model: Dynamic         Param count: 260 	Training error: 0.0169	Testing error: 0.0147
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0138	Testing error: 0.0110
#   > Model: Stacked         Param count: 806 	Training error: 0.0160	Testing error: 0.0153
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0149	Testing error: 0.0119
#   > Model: Dynamic         Param count: 491 	Training error: 0.0148	Testing error: 0.0124
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0139	Testing error: 0.0121
#   > Model: Stacked         Param count: 806 	Training error: 0.0164	Testing error: 0.0166
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0147	Testing error: 0.0123
#   > Model: Dynamic         Param count: 911 	Training error: 0.0132	Testing error: 0.0111
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0119	Testing error: 0.0094
#   > Model: Stacked         Param count: 806 	Training error: 0.0166	Testing error: 0.0147
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0124	Testing error: 0.0091
#   > Model: Dynamic         Param count: 186 	Training error: 0.0128	Testing error: 0.0097
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0120	Testing error: 0.0096
#   > Model: Stacked         Param count: 886 	Training error: 0.0117	Testing error: 0.0101
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0134	Testing error: 0.0104
#   > Model: Dynamic         Param count: 316 	Training error: 0.0124	Testing error: 0.0099
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0103	Testing error: 0.0111
#   > Model: Stacked         Param count: 886 	Training error: 0.0111	Testing error: 0.0104
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0118	Testing error: 0.0099
#   > Model: Dynamic         Param count: 571 	Training error: 0.0106	Testing error: 0.0096
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0115	Testing error: 0.0141
#   > Model: Stacked         Param count: 886 	Training error: 0.0112	Testing error: 0.0098
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0109	Testing error: 0.0085
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0097	Testing error: 0.0112
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0101	Testing error: 0.0169
#   > Model: Stacked         Param count: 886 	Training error: 0.0098	Testing error: 0.0093
#
# ================================ NSE : ASIANPAINT ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0157	Testing error: 0.0049
#   > Model: Dynamic         Param count: 146 	Training error: 0.0186	Testing error: 0.0051
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0143	Testing error: 0.0053
#   > Model: Stacked         Param count: 806 	Training error: 0.0147	Testing error: 0.0063
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0153	Testing error: 0.0053
#   > Model: Dynamic         Param count: 260 	Training error: 0.0142	Testing error: 0.0055
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0138	Testing error: 0.0050
#   > Model: Stacked         Param count: 806 	Training error: 0.0174	Testing error: 0.0065
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0168	Testing error: 0.0060
#   > Model: Dynamic         Param count: 491 	Training error: 0.0137	Testing error: 0.0051
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0131	Testing error: 0.0051
#   > Model: Stacked         Param count: 806 	Training error: 0.0167	Testing error: 0.0100
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0143	Testing error: 0.0050
#   > Model: Dynamic         Param count: 911 	Training error: 0.0128	Testing error: 0.0047
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0131	Testing error: 0.0067
#   > Model: Stacked         Param count: 806 	Training error: 0.0144	Testing error: 0.0054
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0133	Testing error: 0.0061
#   > Model: Dynamic         Param count: 186 	Training error: 0.0135	Testing error: 0.0072
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0113	Testing error: 0.0069
#   > Model: Stacked         Param count: 886 	Training error: 0.0129	Testing error: 0.0061
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0136	Testing error: 0.0074
#   > Model: Dynamic         Param count: 316 	Training error: 0.0129	Testing error: 0.0069
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0115	Testing error: 0.0093
#   > Model: Stacked         Param count: 886 	Training error: 0.0127	Testing error: 0.0108
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0134	Testing error: 0.0070
#   > Model: Dynamic         Param count: 571 	Training error: 0.0125	Testing error: 0.0074
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0123	Testing error: 0.0102
#   > Model: Stacked         Param count: 886 	Training error: 0.0121	Testing error: 0.0088
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0125	Testing error: 0.0089
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0116	Testing error: 0.0078
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0101	Testing error: 0.0200
#   > Model: Stacked         Param count: 886 	Training error: 0.0110	Testing error: 0.0166
#
# ================================ NSE : AXISBANK ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0114	Testing error: 0.0324
#   > Model: Dynamic         Param count: 146 	Training error: 0.0087	Testing error: 0.0217
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0087	Testing error: 0.0288
#   > Model: Stacked         Param count: 806 	Training error: 0.0086	Testing error: 0.0324
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0085	Testing error: 0.0227
#   > Model: Dynamic         Param count: 260 	Training error: 0.0088	Testing error: 0.0163
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0080	Testing error: 0.0099
#   > Model: Stacked         Param count: 806 	Training error: 0.0097	Testing error: 0.0450
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0090	Testing error: 0.0228
#   > Model: Dynamic         Param count: 491 	Training error: 0.0084	Testing error: 0.0201
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0077	Testing error: 0.0131
#   > Model: Stacked         Param count: 806 	Training error: 0.0089	Testing error: 0.0126
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0096	Testing error: 0.0152
#   > Model: Dynamic         Param count: 911 	Training error: 0.0085	Testing error: 0.0382
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0080	Testing error: 0.0104
#   > Model: Stacked         Param count: 806 	Training error: 0.0088	Testing error: 0.0205
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0088	Testing error: 0.1038
#   > Model: Dynamic         Param count: 186 	Training error: 0.0079	Testing error: 0.1195
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0077	Testing error: 0.0338
#   > Model: Stacked         Param count: 886 	Training error: 0.0068	Testing error: 0.0259
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0069	Testing error: 0.0251
#   > Model: Dynamic         Param count: 316 	Training error: 0.0075	Testing error: 0.0282
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0067	Testing error: 0.0759
#   > Model: Stacked         Param count: 886 	Training error: 0.0066	Testing error: 0.0183
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0069	Testing error: 0.0293
#   > Model: Dynamic         Param count: 571 	Training error: 0.0068	Testing error: 0.0458
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0058	Testing error: 0.1075
#   > Model: Stacked         Param count: 886 	Training error: 0.0062	Testing error: 0.0237
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0070	Testing error: 0.0401
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0061	Testing error: 0.0176
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0057	Testing error: 0.0165
#   > Model: Stacked         Param count: 886 	Training error: 0.0062	Testing error: 0.0239
#
# ================================ NSE : BAJAJ-AUTO ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0159	Testing error: 0.0062
#   > Model: Dynamic         Param count: 146 	Training error: 0.0160	Testing error: 0.0065
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0151	Testing error: 0.0062
#   > Model: Stacked         Param count: 806 	Training error: 0.0181	Testing error: 0.0075
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0163	Testing error: 0.0062
#   > Model: Dynamic         Param count: 260 	Training error: 0.0156	Testing error: 0.0063
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0140	Testing error: 0.0068
#   > Model: Stacked         Param count: 806 	Training error: 0.0188	Testing error: 0.0062
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0164	Testing error: 0.0057
#   > Model: Dynamic         Param count: 491 	Training error: 0.0142	Testing error: 0.0058
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0136	Testing error: 0.0058
#   > Model: Stacked         Param count: 806 	Training error: 0.0160	Testing error: 0.0071
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0191	Testing error: 0.0073
#   > Model: Dynamic         Param count: 911 	Training error: 0.0137	Testing error: 0.0059
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0156	Testing error: 0.0090
#   > Model: Stacked         Param count: 806 	Training error: 0.0182	Testing error: 0.0065
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0130	Testing error: 0.0064
#   > Model: Dynamic         Param count: 186 	Training error: 0.0127	Testing error: 0.0063
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0120	Testing error: 0.0066
#   > Model: Stacked         Param count: 886 	Training error: 0.0130	Testing error: 0.0092
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0135	Testing error: 0.0085
#   > Model: Dynamic         Param count: 316 	Training error: 0.0120	Testing error: 0.0080
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0107	Testing error: 0.0077
#   > Model: Stacked         Param count: 886 	Training error: 0.0121	Testing error: 0.0084
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0140	Testing error: 0.0094
#   > Model: Dynamic         Param count: 571 	Training error: 0.0112	Testing error: 0.0080
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0107	Testing error: 0.0072
#   > Model: Stacked         Param count: 886 	Training error: 0.0117	Testing error: 0.0056
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0138	Testing error: 0.0104
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0099	Testing error: 0.0097
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0091	Testing error: 0.0149
#   > Model: Stacked         Param count: 886 	Training error: 0.0117	Testing error: 0.0096
#
# ================================ NSE : BAJFINANCE ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0142	Testing error: 0.0044
#   > Model: Dynamic         Param count: 146 	Training error: 0.0144	Testing error: 0.0045
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0131	Testing error: 0.0041
#   > Model: Stacked         Param count: 806 	Training error: 0.0142	Testing error: 0.0042
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0144	Testing error: 0.0038
#   > Model: Dynamic         Param count: 260 	Training error: 0.0132	Testing error: 0.0039
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0135	Testing error: 0.0052
#   > Model: Stacked         Param count: 806 	Training error: 0.0145	Testing error: 0.0056
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0137	Testing error: 0.0041
#   > Model: Dynamic         Param count: 491 	Training error: 0.0135	Testing error: 0.0043
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0127	Testing error: 0.0039
#   > Model: Stacked         Param count: 806 	Training error: 0.0175	Testing error: 0.0093
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0144	Testing error: 0.0043
#   > Model: Dynamic         Param count: 911 	Training error: 0.0130	Testing error: 0.0037
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0146	Testing error: 0.0071
#   > Model: Stacked         Param count: 806 	Training error: 0.0142	Testing error: 0.0057
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0123	Testing error: 0.0038
#   > Model: Dynamic         Param count: 186 	Training error: 0.0121	Testing error: 0.0040
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0120	Testing error: 0.0041
#   > Model: Stacked         Param count: 886 	Training error: 0.0127	Testing error: 0.0044
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0120	Testing error: 0.0039
#   > Model: Dynamic         Param count: 316 	Training error: 0.0124	Testing error: 0.0044
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0113	Testing error: 0.0034
#   > Model: Stacked         Param count: 886 	Training error: 0.0116	Testing error: 0.0044
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0126	Testing error: 0.0037
#   > Model: Dynamic         Param count: 571 	Training error: 0.0114	Testing error: 0.0039
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0113	Testing error: 0.0042
#   > Model: Stacked         Param count: 886 	Training error: 0.0115	Testing error: 0.0041
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0119	Testing error: 0.0070
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0112	Testing error: 0.0035
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0111	Testing error: 0.0036
#   > Model: Stacked         Param count: 886 	Training error: 0.0118	Testing error: 0.0045
#
# ================================ NSE : BAJAJFINSV ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0141	Testing error: 0.0077
#   > Model: Dynamic         Param count: 146 	Training error: 0.0137	Testing error: 0.0083
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0094	Testing error: 0.0053
#   > Model: Stacked         Param count: 806 	Training error: 0.0107	Testing error: 0.0063
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0115	Testing error: 0.0070
#   > Model: Dynamic         Param count: 260 	Training error: 0.0098	Testing error: 0.0060
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0086	Testing error: 0.0052
#   > Model: Stacked         Param count: 806 	Training error: 0.0114	Testing error: 0.0065
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0092	Testing error: 0.0058
#   > Model: Dynamic         Param count: 491 	Training error: 0.0097	Testing error: 0.0059
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0083	Testing error: 0.0052
#   > Model: Stacked         Param count: 806 	Training error: 0.0103	Testing error: 0.0069
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0092	Testing error: 0.0063
#   > Model: Dynamic         Param count: 911 	Training error: 0.0088	Testing error: 0.0054
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0090	Testing error: 0.0060
#   > Model: Stacked         Param count: 806 	Training error: 0.0121	Testing error: 0.0082
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0090	Testing error: 0.0055
#   > Model: Dynamic         Param count: 186 	Training error: 0.0091	Testing error: 0.0056
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0080	Testing error: 0.0046
#   > Model: Stacked         Param count: 886 	Training error: 0.0077	Testing error: 0.0043
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0081	Testing error: 0.0052
#   > Model: Dynamic         Param count: 316 	Training error: 0.0077	Testing error: 0.0048
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0072	Testing error: 0.0042
#   > Model: Stacked         Param count: 886 	Training error: 0.0072	Testing error: 0.0059
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0079	Testing error: 0.0048
#   > Model: Dynamic         Param count: 571 	Training error: 0.0065	Testing error: 0.0063
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0074	Testing error: 0.0057
#   > Model: Stacked         Param count: 886 	Training error: 0.0075	Testing error: 0.0067
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0080	Testing error: 0.0042
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0064	Testing error: 0.0078
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0063	Testing error: 0.0071
#   > Model: Stacked         Param count: 886 	Training error: 0.0079	Testing error: 0.0084
#
# ================================ NSE : BPCL ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0168	Testing error: 0.0114
#   > Model: Dynamic         Param count: 146 	Training error: 0.0180	Testing error: 0.0144
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0159	Testing error: 0.0103
#   > Model: Stacked         Param count: 806 	Training error: 0.0185	Testing error: 0.0134
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0157	Testing error: 0.0111
#   > Model: Dynamic         Param count: 260 	Training error: 0.0154	Testing error: 0.0113
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0147	Testing error: 0.0113
#   > Model: Stacked         Param count: 806 	Training error: 0.0171	Testing error: 0.0115
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0164	Testing error: 0.0132
#   > Model: Dynamic         Param count: 491 	Training error: 0.0155	Testing error: 0.0125
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0143	Testing error: 0.0110
#   > Model: Stacked         Param count: 806 	Training error: 0.0153	Testing error: 0.0121
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0169	Testing error: 0.0134
#   > Model: Dynamic         Param count: 911 	Training error: 0.0145	Testing error: 0.0107
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0144	Testing error: 0.0112
#   > Model: Stacked         Param count: 806 	Training error: 0.0168	Testing error: 0.0130
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0151	Testing error: 0.0118
#   > Model: Dynamic         Param count: 186 	Training error: 0.0131	Testing error: 0.0110
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0130	Testing error: 0.0104
#   > Model: Stacked         Param count: 886 	Training error: 0.0130	Testing error: 0.0096
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0128	Testing error: 0.0120
#   > Model: Dynamic         Param count: 316 	Training error: 0.0125	Testing error: 0.0106
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0113	Testing error: 0.0106
#   > Model: Stacked         Param count: 886 	Training error: 0.0121	Testing error: 0.0091
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0134	Testing error: 0.0104
#   > Model: Dynamic         Param count: 571 	Training error: 0.0123	Testing error: 0.0105
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0121	Testing error: 0.0104
#   > Model: Stacked         Param count: 886 	Training error: 0.0120	Testing error: 0.0099
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0126	Testing error: 0.0102
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0107	Testing error: 0.0187
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0097	Testing error: 0.0130
#   > Model: Stacked         Param count: 886 	Training error: 0.0122	Testing error: 0.0161
#
# ================================ NSE : BHARTIARTL ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0145	Testing error: 0.0768
#   > Model: Dynamic         Param count: 146 	Training error: 0.0126	Testing error: 0.0425
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0115	Testing error: 0.0488
#   > Model: Stacked         Param count: 806 	Training error: 0.0134	Testing error: 0.0644
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0112	Testing error: 0.0611
#   > Model: Dynamic         Param count: 260 	Training error: 0.0114	Testing error: 0.0374
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0110	Testing error: 0.0383
#   > Model: Stacked         Param count: 806 	Training error: 0.0116	Testing error: 0.0438
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0141	Testing error: 0.0407
#   > Model: Dynamic         Param count: 491 	Training error: 0.0108	Testing error: 0.0299
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0104	Testing error: 0.0193
#   > Model: Stacked         Param count: 806 	Training error: 0.0142	Testing error: 0.0641
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0119	Testing error: 0.0325
#   > Model: Dynamic         Param count: 911 	Training error: 0.0114	Testing error: 0.0422
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0105	Testing error: 0.0230
#   > Model: Stacked         Param count: 806 	Training error: 0.0121	Testing error: 0.0403
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0109	Testing error: 0.0995
#   > Model: Dynamic         Param count: 186 	Training error: 0.0104	Testing error: 0.1089
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0099	Testing error: 0.0608
#   > Model: Stacked         Param count: 886 	Training error: 0.0102	Testing error: 0.0530
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0108	Testing error: 0.1049
#   > Model: Dynamic         Param count: 316 	Training error: 0.0102	Testing error: 0.0686
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0103	Testing error: 0.0661
#   > Model: Stacked         Param count: 886 	Training error: 0.0103	Testing error: 0.0849
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0108	Testing error: 0.0807
#   > Model: Dynamic         Param count: 571 	Training error: 0.0100	Testing error: 0.0419
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0096	Testing error: 0.0434
#   > Model: Stacked         Param count: 886 	Training error: 0.0105	Testing error: 0.0657
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0109	Testing error: 0.1102
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0100	Testing error: 0.0495
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0099	Testing error: 0.0269
#   > Model: Stacked         Param count: 886 	Training error: 0.0099	Testing error: 0.0524
#
# ================================ NSE : BRITANNIA ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0068	Testing error: 0.1177
#   > Model: Dynamic         Param count: 146 	Training error: 0.0068	Testing error: 0.1712
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0066	Testing error: 0.1657
#   > Model: Stacked         Param count: 806 	Training error: 0.0093	Testing error: 0.2997
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0060	Testing error: 0.0829
#   > Model: Dynamic         Param count: 260 	Training error: 0.0054	Testing error: 0.1328
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0054	Testing error: 0.1509
#   > Model: Stacked         Param count: 806 	Training error: 0.0065	Testing error: 0.1857
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0064	Testing error: 0.1002
#   > Model: Dynamic         Param count: 491 	Training error: 0.0062	Testing error: 0.1540
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0050	Testing error: 0.0789
#   > Model: Stacked         Param count: 806 	Training error: 0.0073	Testing error: 0.1909
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0070	Testing error: 0.2369
#   > Model: Dynamic         Param count: 911 	Training error: 0.0058	Testing error: 0.2675
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0051	Testing error: 0.1590
#   > Model: Stacked         Param count: 806 	Training error: 0.0080	Testing error: 0.3161
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0045	Testing error: 0.2631
#   > Model: Dynamic         Param count: 186 	Training error: 0.0045	Testing error: 0.2548
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0044	Testing error: 0.2353
#   > Model: Stacked         Param count: 886 	Training error: 0.0046	Testing error: 0.2612
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0045	Testing error: 0.2554
#   > Model: Dynamic         Param count: 316 	Training error: 0.0044	Testing error: 0.2205
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0042	Testing error: 0.3445
#   > Model: Stacked         Param count: 886 	Training error: 0.0047	Testing error: 0.3886
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0045	Testing error: 0.2331
#   > Model: Dynamic         Param count: 571 	Training error: 0.0045	Testing error: 0.2586
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0044	Testing error: 0.3699
#   > Model: Stacked         Param count: 886 	Training error: 0.0045	Testing error: 0.2961
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0044	Testing error: 0.3515
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0039	Testing error: 0.3190
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0038	Testing error: 0.2864
#   > Model: Stacked         Param count: 886 	Training error: 0.0046	Testing error: 0.3043
#
# ================================ NSE : CIPLA ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0098	Testing error: 0.0099
#   > Model: Dynamic         Param count: 146 	Training error: 0.0095	Testing error: 0.0102
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0095	Testing error: 0.0066
#   > Model: Stacked         Param count: 806 	Training error: 0.0092	Testing error: 0.0091
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0095	Testing error: 0.0128
#   > Model: Dynamic         Param count: 260 	Training error: 0.0091	Testing error: 0.0094
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0091	Testing error: 0.0115
#   > Model: Stacked         Param count: 806 	Training error: 0.0098	Testing error: 0.0113
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0094	Testing error: 0.0109
#   > Model: Dynamic         Param count: 491 	Training error: 0.0088	Testing error: 0.0134
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0083	Testing error: 0.0134
#   > Model: Stacked         Param count: 806 	Training error: 0.0096	Testing error: 0.0137
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0102	Testing error: 0.0124
#   > Model: Dynamic         Param count: 911 	Training error: 0.0084	Testing error: 0.0202
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0082	Testing error: 0.0179
#   > Model: Stacked         Param count: 806 	Training error: 0.0103	Testing error: 0.0283
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0086	Testing error: 0.0130
#   > Model: Dynamic         Param count: 186 	Training error: 0.0086	Testing error: 0.0089
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0082	Testing error: 0.0115
#   > Model: Stacked         Param count: 886 	Training error: 0.0078	Testing error: 0.0185
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0083	Testing error: 0.0136
#   > Model: Dynamic         Param count: 316 	Training error: 0.0084	Testing error: 0.0114
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0084	Testing error: 0.0138
#   > Model: Stacked         Param count: 886 	Training error: 0.0076	Testing error: 0.0224
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0083	Testing error: 0.0116
#   > Model: Dynamic         Param count: 571 	Training error: 0.0078	Testing error: 0.0186
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0068	Testing error: 0.0187
#   > Model: Stacked         Param count: 886 	Training error: 0.0090	Testing error: 0.0247
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0077	Testing error: 0.0125
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0071	Testing error: 0.0268
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0090	Testing error: 0.0204
#   > Model: Stacked         Param count: 886 	Training error: 0.0078	Testing error: 0.0309
#
# ================================ NSE : COALINDIA ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0089	Testing error: 0.0128
#   > Model: Dynamic         Param count: 146 	Training error: 0.0085	Testing error: 0.0152
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0092	Testing error: 0.0136
#   > Model: Stacked         Param count: 806 	Training error: 0.0094	Testing error: 0.0141
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0088	Testing error: 0.0122
#   > Model: Dynamic         Param count: 260 	Training error: 0.0087	Testing error: 0.0113
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0075	Testing error: 0.0062
#   > Model: Stacked         Param count: 806 	Training error: 0.0082	Testing error: 0.0093
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0089	Testing error: 0.0169
#   > Model: Dynamic         Param count: 491 	Training error: 0.0073	Testing error: 0.0092
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0070	Testing error: 0.0091
#   > Model: Stacked         Param count: 806 	Training error: 0.0095	Testing error: 0.0096
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0108	Testing error: 0.0135
#   > Model: Dynamic         Param count: 911 	Training error: 0.0076	Testing error: 0.0084
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0066	Testing error: 0.0174
#   > Model: Stacked         Param count: 806 	Training error: 0.0086	Testing error: 0.0118
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0060	Testing error: 0.0194
#   > Model: Dynamic         Param count: 186 	Training error: 0.0061	Testing error: 0.0285
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0059	Testing error: 0.0200
#   > Model: Stacked         Param count: 886 	Training error: 0.0056	Testing error: 0.0215
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0063	Testing error: 0.0516
#   > Model: Dynamic         Param count: 316 	Training error: 0.0062	Testing error: 0.0370
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0063	Testing error: 0.0301
#   > Model: Stacked         Param count: 886 	Training error: 0.0067	Testing error: 0.0295
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0062	Testing error: 0.0396
#   > Model: Dynamic         Param count: 571 	Training error: 0.0056	Testing error: 0.0216
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0054	Testing error: 0.0109
#   > Model: Stacked         Param count: 886 	Training error: 0.0057	Testing error: 0.0248
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0061	Testing error: 0.0390
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0050	Testing error: 0.0549
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0048	Testing error: 0.0256
#   > Model: Stacked         Param count: 886 	Training error: 0.0058	Testing error: 0.0261
#
# ================================ NSE : DIVISLAB ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0163	Testing error: 0.0460
#   > Model: Dynamic         Param count: 146 	Training error: 0.0147	Testing error: 0.0375
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0136	Testing error: 0.0318
#   > Model: Stacked         Param count: 806 	Training error: 0.0143	Testing error: 0.0390
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0135	Testing error: 0.0378
#   > Model: Dynamic         Param count: 260 	Training error: 0.0135	Testing error: 0.0309
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0139	Testing error: 0.0258
#   > Model: Stacked         Param count: 806 	Training error: 0.0127	Testing error: 0.0336
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0135	Testing error: 0.0306
#   > Model: Dynamic         Param count: 491 	Training error: 0.0126	Testing error: 0.0307
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0119	Testing error: 0.0281
#   > Model: Stacked         Param count: 806 	Training error: 0.0151	Testing error: 0.0482
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0135	Testing error: 0.0415
#   > Model: Dynamic         Param count: 911 	Training error: 0.0121	Testing error: 0.0321
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0123	Testing error: 0.0292
#   > Model: Stacked         Param count: 806 	Training error: 0.0151	Testing error: 0.0431
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0115	Testing error: 0.0428
#   > Model: Dynamic         Param count: 186 	Training error: 0.0118	Testing error: 0.0441
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0110	Testing error: 0.0466
#   > Model: Stacked         Param count: 886 	Training error: 0.0115	Testing error: 0.0563
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0118	Testing error: 0.0412
#   > Model: Dynamic         Param count: 316 	Training error: 0.0115	Testing error: 0.0404
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0112	Testing error: 0.0466
#   > Model: Stacked         Param count: 886 	Training error: 0.0115	Testing error: 0.0490
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0118	Testing error: 0.0516
#   > Model: Dynamic         Param count: 571 	Training error: 0.0112	Testing error: 0.0411
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0105	Testing error: 0.0422
#   > Model: Stacked         Param count: 886 	Training error: 0.0108	Testing error: 0.0629
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0104	Testing error: 0.0477
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0092	Testing error: 0.0433
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0097	Testing error: 0.0402
#   > Model: Stacked         Param count: 886 	Training error: 0.0077	Testing error: 0.0770
#
# ================================ NSE : DRREDDY ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0142	Testing error: 0.0107
# ...
#   > Model: Stacked         Param count: 806 	Training error: 0.0053	Testing error: 0.0020
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0051	Testing error: 0.0021
#   > Model: Dynamic         Param count: 911 	Training error: 0.0047	Testing error: 0.0029
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0047	Testing error: 0.0021
#   > Model: Stacked         Param count: 806 	Training error: 0.0056	Testing error: 0.0020
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0031	Testing error: 0.0019
#   > Model: Dynamic         Param count: 186 	Training error: 0.0039	Testing error: 0.0018
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0030	Testing error: 0.0016
#   > Model: Stacked         Param count: 886 	Training error: 0.0032	Testing error: 0.0018
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0030	Testing error: 0.0021
#   > Model: Dynamic         Param count: 316 	Training error: 0.0032	Testing error: 0.0017
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0027	Testing error: 0.0021
#   > Model: Stacked         Param count: 886 	Training error: 0.0030	Testing error: 0.0023
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0031	Testing error: 0.0023
#   > Model: Dynamic         Param count: 571 	Training error: 0.0028	Testing error: 0.0023
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0025	Testing error: 0.0021
#   > Model: Stacked         Param count: 886 	Training error: 0.0031	Testing error: 0.0032
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0032	Testing error: 0.0026
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0026	Testing error: 0.0017
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0025	Testing error: 0.0016
#   > Model: Stacked         Param count: 886 	Training error: 0.0030	Testing error: 0.0016
#
# ================================ NSE : TITAN ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0138	Testing error: 0.0095
#   > Model: Dynamic         Param count: 146 	Training error: 0.0160	Testing error: 0.0103
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0123	Testing error: 0.0074
#   > Model: Stacked         Param count: 806 	Training error: 0.0133	Testing error: 0.0096
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0135	Testing error: 0.0091
#   > Model: Dynamic         Param count: 260 	Training error: 0.0137	Testing error: 0.0088
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0138	Testing error: 0.0079
#   > Model: Stacked         Param count: 806 	Training error: 0.0142	Testing error: 0.0090
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0147	Testing error: 0.0085
#   > Model: Dynamic         Param count: 491 	Training error: 0.0128	Testing error: 0.0079
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0132	Testing error: 0.0103
#   > Model: Stacked         Param count: 806 	Training error: 0.0162	Testing error: 0.0094
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0149	Testing error: 0.0088
#   > Model: Dynamic         Param count: 911 	Training error: 0.0128	Testing error: 0.0082
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0119	Testing error: 0.0099
#   > Model: Stacked         Param count: 806 	Training error: 0.0165	Testing error: 0.0103
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0115	Testing error: 0.0089
#   > Model: Dynamic         Param count: 186 	Training error: 0.0113	Testing error: 0.0088
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0111	Testing error: 0.0089
#   > Model: Stacked         Param count: 886 	Training error: 0.0108	Testing error: 0.0090
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0110	Testing error: 0.0107
#   > Model: Dynamic         Param count: 316 	Training error: 0.0113	Testing error: 0.0082
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0098	Testing error: 0.0075
#   > Model: Stacked         Param count: 886 	Training error: 0.0105	Testing error: 0.0079
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0113	Testing error: 0.0091
#   > Model: Dynamic         Param count: 571 	Training error: 0.0107	Testing error: 0.0072
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0106	Testing error: 0.0068
#   > Model: Stacked         Param count: 886 	Training error: 0.0103	Testing error: 0.0088
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0115	Testing error: 0.0093
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0101	Testing error: 0.0067
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0094	Testing error: 0.0074
#   > Model: Stacked         Param count: 886 	Training error: 0.0113	Testing error: 0.0091
#
# ================================ NSE : UPL ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0187	Testing error: 0.0090
#   > Model: Dynamic         Param count: 146 	Training error: 0.0163	Testing error: 0.0081
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0164	Testing error: 0.0086
#   > Model: Stacked         Param count: 806 	Training error: 0.0163	Testing error: 0.0079
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0172	Testing error: 0.0084
#   > Model: Dynamic         Param count: 260 	Training error: 0.0162	Testing error: 0.0081
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0173	Testing error: 0.0085
#   > Model: Stacked         Param count: 806 	Training error: 0.0179	Testing error: 0.0098
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0174	Testing error: 0.0088
#   > Model: Dynamic         Param count: 491 	Training error: 0.0153	Testing error: 0.0078
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0151	Testing error: 0.0083
#   > Model: Stacked         Param count: 806 	Training error: 0.0190	Testing error: 0.0100
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0167	Testing error: 0.0075
#   > Model: Dynamic         Param count: 911 	Training error: 0.0146	Testing error: 0.0089
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0144	Testing error: 0.0082
#   > Model: Stacked         Param count: 806 	Training error: 0.0212	Testing error: 0.0159
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0143	Testing error: 0.0070
#   > Model: Dynamic         Param count: 186 	Training error: 0.0143	Testing error: 0.0072
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0138	Testing error: 0.0071
#   > Model: Stacked         Param count: 886 	Training error: 0.0142	Testing error: 0.0077
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0146	Testing error: 0.0067
#   > Model: Dynamic         Param count: 316 	Training error: 0.0137	Testing error: 0.0072
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0127	Testing error: 0.0074
#   > Model: Stacked         Param count: 886 	Training error: 0.0129	Testing error: 0.0074
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0146	Testing error: 0.0075
#   > Model: Dynamic         Param count: 571 	Training error: 0.0136	Testing error: 0.0068
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0122	Testing error: 0.0068
#   > Model: Stacked         Param count: 886 	Training error: 0.0136	Testing error: 0.0082
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0149	Testing error: 0.0073
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0134	Testing error: 0.0074
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0125	Testing error: 0.0089
#   > Model: Stacked         Param count: 886 	Training error: 0.0138	Testing error: 0.0098
#
# ================================ NSE : ULTRACEMCO ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0098	Testing error: 0.0056
#   > Model: Dynamic         Param count: 146 	Training error: 0.0085	Testing error: 0.0054
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0082	Testing error: 0.0052
#   > Model: Stacked         Param count: 806 	Training error: 0.0092	Testing error: 0.0067
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0091	Testing error: 0.0056
#   > Model: Dynamic         Param count: 260 	Training error: 0.0075	Testing error: 0.0051
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0075	Testing error: 0.0061
#   > Model: Stacked         Param count: 806 	Training error: 0.0094	Testing error: 0.0074
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0076	Testing error: 0.0070
#   > Model: Dynamic         Param count: 491 	Training error: 0.0082	Testing error: 0.0068
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0079	Testing error: 0.0076
#   > Model: Stacked         Param count: 806 	Training error: 0.0083	Testing error: 0.0077
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0084	Testing error: 0.0160
#   > Model: Dynamic         Param count: 911 	Training error: 0.0072	Testing error: 0.0120
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0066	Testing error: 0.0153
#   > Model: Stacked         Param count: 806 	Training error: 0.0086	Testing error: 0.0162
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0079	Testing error: 0.0046
#   > Model: Dynamic         Param count: 186 	Training error: 0.0080	Testing error: 0.0054
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0071	Testing error: 0.0048
#   > Model: Stacked         Param count: 886 	Training error: 0.0071	Testing error: 0.0098
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0076	Testing error: 0.0047
#   > Model: Dynamic         Param count: 316 	Training error: 0.0071	Testing error: 0.0050
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0064	Testing error: 0.0076
#   > Model: Stacked         Param count: 886 	Training error: 0.0076	Testing error: 0.0171
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0070	Testing error: 0.0061
#   > Model: Dynamic         Param count: 571 	Training error: 0.0063	Testing error: 0.0117
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0056	Testing error: 0.0141
#   > Model: Stacked         Param count: 886 	Training error: 0.0063	Testing error: 0.0127
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0064	Testing error: 0.0186
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0057	Testing error: 0.0245
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0056	Testing error: 0.0189
#   > Model: Stacked         Param count: 886 	Training error: 0.0057	Testing error: 0.0522
#
# ================================ NSE : WIPRO ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0039	Testing error: 0.0027
#   > Model: Dynamic         Param count: 146 	Training error: 0.0046	Testing error: 0.0035
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0037	Testing error: 0.0026
#   > Model: Stacked         Param count: 806 	Training error: 0.0044	Testing error: 0.0027
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0038	Testing error: 0.0028
#   > Model: Dynamic         Param count: 260 	Training error: 0.0034	Testing error: 0.0013
#   > Model: Bidirectional   Param count: 617 	Training error: 0.0035	Testing error: 0.0026
#   > Model: Stacked         Param count: 806 	Training error: 0.0041	Testing error: 0.0024
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0032	Testing error: 0.0018
#   > Model: Dynamic         Param count: 491 	Training error: 0.0036	Testing error: 0.0022
#   > Model: Bidirectional   Param count: 1181 	Training error: 0.0036	Testing error: 0.0011
#   > Model: Stacked         Param count: 806 	Training error: 0.0042	Testing error: 0.0019
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0038	Testing error: 0.0018
#   > Model: Dynamic         Param count: 911 	Training error: 0.0031	Testing error: 0.0019
#   > Model: Bidirectional   Param count: 2213 	Training error: 0.0030	Testing error: 0.0012
#   > Model: Stacked         Param count: 806 	Training error: 0.0046	Testing error: 0.0029
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0027	Testing error: 0.0021
#   > Model: Dynamic         Param count: 186 	Training error: 0.0027	Testing error: 0.0021
#   > Model: Bidirectional   Param count: 421 	Training error: 0.0025	Testing error: 0.0020
#   > Model: Stacked         Param count: 886 	Training error: 0.0028	Testing error: 0.0027
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0024	Testing error: 0.0024
#   > Model: Dynamic         Param count: 316 	Training error: 0.0024	Testing error: 0.0018
#   > Model: Bidirectional   Param count: 729 	Training error: 0.0022	Testing error: 0.0016
#   > Model: Stacked         Param count: 886 	Training error: 0.0025	Testing error: 0.0021
#
# Window size : 10
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0026	Testing error: 0.0037
#   > Model: Dynamic         Param count: 571 	Training error: 0.0027	Testing error: 0.0016
#   > Model: Bidirectional   Param count: 1341 	Training error: 0.0021	Testing error: 0.0011
#   > Model: Stacked         Param count: 886 	Training error: 0.0025	Testing error: 0.0021
#
# Window size : 14
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0023	Testing error: 0.0025
#   > Model: Dynamic         Param count: 1023 	Training error: 0.0022	Testing error: 0.0009
#   > Model: Bidirectional   Param count: 2437 	Training error: 0.0020	Testing error: 0.0012
#   > Model: Stacked         Param count: 886 	Training error: 0.0024	Testing error: 0.0017
#
# Successfully evaluated all data and saved testing logs in "artifacts/Testing_Logs.json" and metrics of best performing model at "artifacts/Best_Model_Params.json".
