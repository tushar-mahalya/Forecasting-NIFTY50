# %%
# Hardware configuration 
# Using tf-cpu-310 Conda Env
import tensorflow as tf
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3319543173320580025
#  xla_global_id: -1]

# %%
# Importing important libraries
import json

# Importing modules from Source Code
from src.pipeline.testing import test_models
from src.components.models import all_models

# %%
# Creating the dictionary of the data_map.json file
with open('/home/studio-lab-user/sagemaker-studiolab-notebooks/Forecasting-NIFTY50/artifacts/data_map.json', 'r') as file:
    data_map = json.load(file)

# %%
norm_data_dict = dict()
for ticker in data_map.keys():
    norm_data_dict[ticker] = data_map[ticker]['Normalized Data']

# %%
my_models = all_models()
my_models['Dynamic'].layers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 my_models = all_models()
# ----> 2 my_models['Dynamic'].layers
#
# AttributeError: 'function' object has no attribute 'layers'

# %%
window_size_list = [5,7]
epochs = 2

# %%
test_models(data_dict = norm_data_dict,
            epochs = epochs,
            models = my_models,
            window_sizes = window_size_list)
# Out:
# ================================ NSE : ADANIENT ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.1379	Testing error: 0.3886
#   > Model: Dynamic         Param count: 146 	Training error: 0.3479	Testing error: 0.9969
#   > Model: Bidirectional   Param count: 341 	Training error: 0.2885	Testing error: 0.7792
#   > Model: Stacked         Param count: 806 	Training error: 0.2852	Testing error: 0.6917
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.2321	Testing error: 0.4984
#   > Model: Dynamic         Param count: 260 	Training error: 0.0969	Testing error: 0.3495
#   > Model: Bidirectional   Param count: 617 	Training error: 0.1866	Testing error: 0.5068
#   > Model: Stacked         Param count: 806 	Training error: 0.1111	Testing error: 0.3817
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.2648	Testing error: 0.4866
#   > Model: Dynamic         Param count: 186 	Training error: 0.0681	Testing error: 0.2158
#   > Model: Bidirectional   Param count: 421 	Training error: 0.2610	Testing error: 0.7863
#   > Model: Stacked         Param count: 886 	Training error: 0.2169	Testing error: 0.6384
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.0688	Testing error: 0.1190
#   > Model: Dynamic         Param count: 316 	Training error: 0.0983	Testing error: 0.2908
#   > Model: Bidirectional   Param count: 729 	Training error: 0.2697	Testing error: 1.0096
#   > Model: Stacked         Param count: 886 	Training error: 0.1817	Testing error: 0.5473
#
# ================================ NSE : ADANIPORTS ================================
#
# --------------------------------------------------------------- Simple Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.0931	Testing error: 0.0759
#   > Model: Dynamic         Param count: 146 	Training error: 0.3378	Testing error: 0.3000
#   > Model: Bidirectional   Param count: 341 	Training error: 0.0593	Testing error: 0.0462
#   > Model: Stacked         Param count: 806 	Training error: 0.1630	Testing error: 0.1551
#
# Window size : 7
# ----------------
#   > Model: Fixed           Param count: 146 	Training error: 0.5245	Testing error: 0.4231
#   > Model: Dynamic         Param count: 260 	Training error: 0.1553	Testing error: 0.1212
#   > Model: Bidirectional   Param count: 617 	Training error: 0.1085	Testing error: 0.1191
#   > Model: Stacked         Param count: 806 	Training error: 0.2331	Testing error: 0.2353
#
# --------------------------------------------------------------- Multi Sequence
#
# Window size : 5
# ----------------
#   > Model: Fixed           Param count: 186 	Training error: 0.1402	Testing error: 0.1069
#   > Model: Dynamic         Param count: 186 	Training error: 0.2154	Testing error: 0.1457
#   > Model: Bidirectional   Param count: 421 	Training error: 0.5767	Testing error: 0.5494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 test_models(data_dict = norm_data_dict,
#       2             epochs = epochs,
#       3             models = my_models,
#       4             window_sizes = window_size_list)
#
# File ~/sagemaker-studiolab-notebooks/Forecasting-NIFTY50/src/pipeline/testing.py:46, in test_models(data_dict, epochs, models, window_sizes)
#      42 model = models[model_type](X_train, y_train, 0.001,
#      43                            model_name=f'{ticker.replace("&", "and")}_Model')
#      45 # fitting model
# ---> 46 model.fit(X_train, y_train, epochs=epochs, batch_size=50, verbose=0)
#      48 # printing training and testing errors
#      49 training_error = model.evaluate(X_train, y_train, verbose=0)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:945, in Function._call(self, *args, **kwds)
#     941     pass  # Fall through to cond-based initialization.
#     942   else:
#     943     # Lifting succeeded, so variables are initialized and we can run the
#     944     # no_variable_creation function.
# --> 945     return self._no_variable_creation_fn(*args, **kwds)
#     946 else:
#     947   _, _, filtered_flat_args = (
#     948       self._variable_creation_fn._function_spec  # pylint: disable=protected-access
#     949       .canonicalize_function_inputs(
#     950           args, kwds))
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:133, in TracingCompiler.__call__(self, *args, **kwargs)
#     130 """Calls a graph function specialized to the inputs."""
#     131 with self._lock:
#     132   (concrete_function,
# --> 133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:360, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     357   # Only get placeholders for arguments, not captures
#     358   args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
# --> 360 concrete_function = self._create_concrete_function(args, kwargs)
#     362 graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#     363 # Maintain the list of all captures
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:284, in TracingCompiler._create_concrete_function(self, args, kwargs)
#     279 missing_arg_names = [
#     280     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#     281 ]
#     282 arg_names = base_arg_names + missing_arg_names
#     283 concrete_function = monomorphic_function.ConcreteFunction(
# --> 284     func_graph_module.func_graph_from_py_func(
#     285         self._name,
#     286         self._python_function,
#     287         args,
#     288         kwargs,
#     289         None,
#     290         autograph=self._autograph,
#     291         autograph_options=self._autograph_options,
#     292         arg_names=arg_names,
#     293         capture_by_value=self._capture_by_value),
#     294     self._function_attributes,
#     295     spec=self.function_spec,
#     296     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     297     # scope. This is not the default behavior since it gets used in some
#     298     # places (like Keras) where the FuncGraph lives longer than the
#     299     # ConcreteFunction.
#     300     shared_func_graph=False)
#     301 return concrete_function
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1283, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1280 else:
#    1281   _, original_func = tf_decorator.unwrap(python_func)
# -> 1283 func_outputs = python_func(*func_args, **func_kwargs)
#    1285 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1286 # TensorArrays and `None`s.
#    1287 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:645, in Function._compiler_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     641 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     642   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     643   # the function a weak reference to itself to avoid a reference cycle.
#     644   with OptionalXlaContext(compile_with_xla):
# --> 645     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     646   return out
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1258, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1256 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1257 try:
# -> 1258   return autograph.converted_call(
#    1259       original_func,
#    1260       args,
#    1261       kwargs,
#    1262       options=autograph.ConversionOptions(
#    1263           recursive=True,
#    1264           optional_features=autograph_options,
#    1265           user_requested=True,
#    1266       ))
#    1267 except Exception as e:  # pylint:disable=broad-except
#    1268   if hasattr(e, "ag_error_metadata"):
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file1pluynh_.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/training.py:1233, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1229     run_step = tf.function(
#    1230         run_step, jit_compile=True, reduce_retracing=True
#    1231     )
#    1232 data = next(iterator)
# -> 1233 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1234 outputs = reduce_per_replica(
#    1235     outputs,
#    1236     self.distribute_strategy,
#    1237     reduction=self.distribute_reduction_method,
#    1238 )
#    1239 return outputs
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:1316, in StrategyBase.run(***failed resolving arguments***)
#    1311 with self.scope():
#    1312   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1313   # applied when the caller is also in Eager mode.
#    1314   fn = autograph.tf_convert(
#    1315       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:2895, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2893   kwargs = {}
#    2894 with self._container_strategy().scope():
# -> 2895   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3696, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3694 def _call_for_each_replica(self, fn, args, kwargs):
#    3695   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696     return fn(*args, **kwargs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/training.py:1222, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1221 def run_step(data):
# -> 1222     outputs = model.train_step(data)
#    1223     # Ensure counter is updated only if `train_step` succeeds.
#    1224     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/training.py:1023, in Model.train_step(self, data)
#    1021 # Run forward pass.
#    1022 with tf.GradientTape() as tape:
# -> 1023     y_pred = self(x, training=True)
#    1024     loss = self.compute_loss(x, y, y_pred, sample_weight)
#    1025 self._validate_target_and_loss(y, loss)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/training.py:561, in Model.__call__(self, *args, **kwargs)
#     557         super().__call__(inputs, *copied_args, **copied_kwargs)
#     559     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 561 return super().__call__(*args, **kwargs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/sequential.py:413, in Sequential.call(self, inputs, training, mask)
#     411     if not self.built:
#     412         self._init_graph_network(self.inputs, self.outputs)
# --> 413     return super().call(inputs, training=training, mask=mask)
#     415 outputs = inputs  # handle the corner case where self.layers is empty
#     416 for layer in self.layers:
#     417     # During each iteration, `inputs` are the inputs to `layer`, and
#     418     # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     419     # end of each iteration `inputs` is set to `outputs` to prepare for
#     420     # the next layer.
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/functional.py:511, in Functional.call(self, inputs, training, mask)
#     492 @doc_controls.do_not_doc_inheritable
#     493 def call(self, inputs, training=None, mask=None):
#     494     """Calls the model on new inputs.
#     495
#     496     In this case `call` just reapplies
#    (...)
#     509         a list of tensors if there are more than one outputs.
#     510     """
# --> 511     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/functional.py:668, in Functional._run_internal_graph(self, inputs, training, mask)
#     665     continue  # Node is not computable, try skipping.
#     667 args, kwargs = node.map_arguments(tensor_dict)
# --> 668 outputs = node.layer(*args, **kwargs)
#     670 # Update tensor_dict.
#     671 for x_id, y in zip(
#     672     node.flat_output_ids, tf.nest.flatten(outputs)
#     673 ):
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/layers/rnn/base_rnn.py:556, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     551 inputs, initial_state, constants = rnn_utils.standardize_args(
#     552     inputs, initial_state, constants, self._num_constants
#     553 )
#     555 if initial_state is None and constants is None:
# --> 556     return super().__call__(inputs, **kwargs)
#     558 # If any of `initial_state` or `constants` are specified and are Keras
#     559 # tensors, then add them to the inputs and temporarily modify the
#     560 # input_spec to include them.
#     562 additional_inputs = []
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/layers/rnn/lstm.py:751, in LSTM.call(self, inputs, mask, training, initial_state)
#     737                 (
#     738                     last_output,
#     739                     outputs,
#    (...)
#     742                     runtime,
#     743                 ) = standard_lstm(**normal_lstm_kwargs)
#     744         else:
#     745             (
#     746                 last_output,
#     747                 outputs,
#     748                 new_h,
#     749                 new_c,
#     750                 runtime,
# --> 751             ) = lstm_with_backend_selection(**normal_lstm_kwargs)
#     753     states = [new_h, new_c]
#     755 if self.stateful:
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/layers/rnn/lstm.py:1356, in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#    1351     # Call the normal LSTM impl and register the cuDNN impl function. The
#    1352     # grappler will kick in during session execution to optimize the graph.
#    1353     last_output, outputs, new_h, new_c, runtime = defun_standard_lstm(
#    1354         **params
#    1355     )
# -> 1356     gru_lstm_utils.function_register(defun_gpu_lstm, **params)
#    1358 return last_output, outputs, new_h, new_c, runtime
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/keras/layers/rnn/gru_lstm_utils.py:259, in function_register(func, *args, **kwargs)
#     257 concrete_func = func.get_concrete_function(*args, **kwargs)
#     258 concrete_func.add_to_graph()
# --> 259 concrete_func.add_gradient_functions_to_graph()
#     260 return concrete_func
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1998, in ConcreteFunction.add_gradient_functions_to_graph(self, g)
#    1995   g = ops.get_default_graph()
#    1996 self._delayed_rewrite_functions.forward().add_to_graph(g)
#    1997 forward_function, backward_function = (
# -> 1998     self._delayed_rewrite_functions.forward_backward())
#    1999 forward_function.add_to_graph(g)
#    2000 backward_function.add_to_graph(g)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:480, in _DelayedRewriteGradientFunctions.forward_backward(self, num_doutputs)
#     478 if forward_backward is not None:
#     479   return forward_backward
# --> 480 forward, backward = self._construct_forward_backward(num_doutputs)
#     481 self._cached_function_pairs[num_doutputs] = (forward, backward)
#     482 return forward, backward
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:523, in _DelayedRewriteGradientFunctions._construct_forward_backward(self, num_doutputs)
#     520 with self._func_graph.as_default():
#     521   backwards_graph = func_graph_module.FuncGraph(
#     522       _backward_name(self._func_graph.name))
# --> 523   func_graph_module.func_graph_from_py_func(
#     524       name=backwards_graph.name,
#     525       python_func=_backprop_function,
#     526       args=[], kwargs={},
#     527       signature=signature,
#     528       func_graph=backwards_graph)
#     529   backwards_graph_captures = backwards_graph.external_captures
#     530   captures_from_forward = [
#     531       c for c in backwards_graph_captures if
#     532       not isinstance(c, ops.EagerTensor) and c.graph is self._func_graph]
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1178, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1175 else:
#    1176   deps_control_manager = ops.NullContextmanager()
# -> 1178 with func_graph.as_default(), deps_control_manager as deps_ctx:
#    1179   current_scope = variable_scope.get_variable_scope()
#    1180   default_use_resource = current_scope.use_resource
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/framework/auto_control_deps.py:464, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     461 resource_inputs = set()
#     462 # Check for any resource inputs. If we find any, we update control_inputs
#     463 # and last_write_to_resource.
# --> 464 for inp, resource_type in _get_resource_inputs(op):
#     465   is_read = resource_type == ResourceType.READ_ONLY
#     466   input_id = ops.tensor_id(inp)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/framework/auto_control_deps.py:671, in _get_resource_inputs(op)
#     665 saturated = True
#     666 for key in _acd_resource_resolvers_registry.list():
#     667   # Resolvers should return true if they are updating the list of
#     668   # resource_inputs.
#     669   # TODO(srbs): An alternate would be to just compare the old and new set
#     670   # but that may not be as fast.
# --> 671   updated = _acd_resource_resolvers_registry.lookup(key)(op, reads, writes)
#     672   if updated:
#     673     # Conservatively remove any resources from `reads` that are also writes.
#     674     reads = reads.difference(writes)
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:6559, in _resource_resolver(op, resource_reads, resource_writes)
#    6556       updated = True
#    6557       resource_writes.add(inp)
# -> 6559 if op.type in [
#    6560     "IteratorGetNext", "IteratorGetNextSync", "IteratorGetNextAsOptional"
#    6561 ]:
#    6562   iterator_resource = op.inputs[0]
#    6563   make_iterator_ops = [
#    6564       op for op in iterator_resource.consumers() if op.type == "MakeIterator"
#    6565   ]
#
# File ~/.conda/envs/tf-cpu-310/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:2581, in Operation.type(self)
#    2578 @property
#    2579 def type(self):
#    2580   """The type of the op (e.g. `"MatMul"`)."""
# -> 2581   return pywrap_tf_session.TF_OperationOpType(self._c_op)
#
# KeyboardInterrupt:
